# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
train = pd.read_csv('TitanicSolution/titanic_train.csv')
test = pd.read_csv('TitanicSolution/titanic_test.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d2bab1820af> in <module>
# ----> 1 train.head(10)
#
# NameError: name 'train' is not defined
